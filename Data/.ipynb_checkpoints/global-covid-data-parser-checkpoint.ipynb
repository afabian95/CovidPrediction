# %%
from datetime import *
import pandas as pd
import warnings

warnings.filterwarnings('ignore')

# %%
data = pd.read_csv(".\\Raw Data\\Covid Numbers\\global-covid-data.csv")

countries = data.Country.unique()
country_count = 0
for country in countries:
    country_data = data[(data == country).any(axis=1)]
    country_data.index = range(len(country_data))
    new_data = pd.DataFrame(columns = ['date', 'cases', 'deaths'])

    day = datetime(2020, 1, 1)
    first_day_index = -1
    last_day_index = -1
    increment = 0
    while day < datetime.now():
        date_str = day.strftime("%Y-%m-%d")
        cases = ''
        deaths = ''
        # Search the entire csv file only for the first two dates
        if last_day_index == -1:
            for index, row in country_data.iterrows():
                if date_str == row['Date_reported']:
                    cases = row['Cumulative_cases']
                    deaths = row['Cumulative_deaths']
                    if first_day_index == -1:
                        first_day_index = index
                    elif last_day_index == -1:
                        last_day_index = index
                        increment = last_day_index - first_day_index
        # Once the first two dates are found, continue incrementally in that direction until end of file
        else:
            last_day_index += increment
            if (last_day_index >= 0 and last_day_index < len(country_data)):
                row = country_data.iloc[last_day_index]
                cases = row['Cumulative_cases']
                deaths = row['Cumulative_deaths']
                        
        new_data = new_data.append({'date': date_str, 'cases': cases, 'deaths': deaths}, ignore_index=True)
        day = day + timedelta(days=1)

        new_data.to_csv('.\\Parsed Data\\' + country + '.csv', index=False)
    
    country_count += 1
    print(str(country) + ' (' + str(country_count) + '/' + str(len(countries)) + ') completed')
# Out:
# Afghanistan (1/236) completed
# Albania (2/236) completed
# Algeria (3/236) completed
# American Samoa (4/236) completed
# Andorra (5/236) completed
# Angola (6/236) completed
# Anguilla (7/236) completed
# Antigua and Barbuda (8/236) completed
# Argentina (9/236) completed
# Armenia (10/236) completed
# Aruba (11/236) completed
# Australia (12/236) completed
# Austria (13/236) completed
# Azerbaijan (14/236) completed
# Bahamas (15/236) completed
# Bahrain (16/236) completed
# Bangladesh (17/236) completed
# Barbados (18/236) completed
# Belarus (19/236) completed
# Belgium (20/236) completed
# Belize (21/236) completed
# Benin (22/236) completed
# Bermuda (23/236) completed
# Bhutan (24/236) completed
# Bolivia (Plurinational State of) (25/236) completed
# Bonaire (26/236) completed
# Bosnia and Herzegovina (27/236) completed
# Botswana (28/236) completed
# Brazil (29/236) completed
# British Virgin Islands (30/236) completed
# Brunei Darussalam (31/236) completed
# Bulgaria (32/236) completed
# Burkina Faso (33/236) completed
# Burundi (34/236) completed
# Cabo Verde (35/236) completed
# Cambodia (36/236) completed
# Cameroon (37/236) completed
# Canada (38/236) completed
# Cayman Islands (39/236) completed
# Central African Republic (40/236) completed
# Chad (41/236) completed
# Chile (42/236) completed
# China (43/236) completed
# Colombia (44/236) completed
# Comoros (45/236) completed
# Congo (46/236) completed
# Cook Islands (47/236) completed
# Costa Rica (48/236) completed
