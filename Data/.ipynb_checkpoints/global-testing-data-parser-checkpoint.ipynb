# %%
from datetime import *
import pandas as pd
import warnings

warnings.filterwarnings('ignore')

# %%
test_data = pd.read_csv(".\\Raw Data\\Testing Numbers\\global-testing-data.csv")

countries = test_data.Entity.unique()

country_count = 0
for country in countries:
    country_name = country.split(' - ')[0]
    country_data = test_data[(test_data == country).any(axis=1)]
    country_data.index = range(len(country_data))
    file_path = '.\\Parsed Data\\Global\\' + country_name + '.csv'
    try:
        new_data = pd.read_csv(file_path)

        all_daily_tests = []
        day = datetime(2020, 1, 1)
        first_day_index = -1
        last_day_index = -1
        increment = 0
        while day < datetime(2021, 4, 16):
            date_str = day.strftime("%Y-%m-%d")
            daily_tests = ''
            # Search the entire csv file only for the first two dates
            if last_day_index == -1:
                for index, row in country_data.iterrows():
                    if date_str == row['Date']:
                        daily_tests = row['Daily change in cumulative total']
                        if first_day_index == -1:
                            first_day_index = index
                        elif last_day_index == -1:
                            last_day_index = index
                            increment = last_day_index - first_day_index
            # Once the first two dates are found, continue incrementally in that direction until end of file
            else:
                last_day_index += increment
                if (last_day_index >= 0 and last_day_index < len(country_data)):
                    row = country_data.iloc[last_day_index]
                    daily_tests = row['Daily change in cumulative total']

            all_daily_tests.append(daily_tests)
            day = day + timedelta(days=1)

        new_data['daily_tests'] = all_daily_tests

        country_count += 1
        new_data.to_csv(file_path, index=False)
        print(country_name + ' (' + str(country_count) + '/' + str(len(countries)) + ') completed')
    except:
        country_count += 1
        print(country_name + ' (' + str(country_count) + '/' + str(len(countries)) + ') could not be found')
# Out:
# Albania (1/124) completed
# Andorra (2/124) completed
# Argentina (3/124) completed
# Armenia (4/124) completed
# Australia (5/124) completed
# Austria (6/124) completed
# Bahrain (7/124) completed
# Bangladesh (8/124) completed
# Belarus (9/124) completed
# Belgium (10/124) completed
# Bhutan (11/124) completed
# Bolivia (12/124) completed
# Bosnia and Herzegovina (13/124) completed
# Brazil (14/124) completed
# Bulgaria (15/124) completed
# Canada (16/124) completed
# Canada (17/124) completed
# Cape Verde (18/124) completed
# Chile (19/124) completed
# China (20/124) completed
# Colombia (21/124) completed
# Costa Rica (22/124) completed
# Cote d'Ivoire (23/124) completed
# Croatia (24/124) completed
# Cuba (25/124) completed
# Cyprus (26/124) completed
# Czechia (27/124) completed
# Democratic Republic of Congo (28/124) completed
# Denmark (29/124) completed
# Dominican Republic (30/124) completed
# Ecuador (31/124) completed
# El Salvador (32/124) completed
# Estonia (33/124) completed
# Ethiopia (34/124) completed
# Fiji (35/124) completed
# Finland (36/124) completed
# France (37/124) completed
# Gambia (38/124) completed
# Germany (39/124) completed
# Ghana (40/124) completed
# Greece (41/124) completed
# Guatemala (42/124) completed
# Hong Kong (43/124) could not be found
# Hungary (44/124) completed
# Iceland (45/124) completed
# India (46/124) completed
# Indonesia (47/124) completed
# Iran (48/124) completed
# Iraq (49/124) completed
# Ireland (50/124) completed
# Israel (51/124) completed
# Italy (52/124) completed
# Italy (53/124) completed
# Jamaica (54/124) completed
# Japan (55/124) completed
# Jordan (56/124) completed
# Kazakhstan (57/124) completed
# Kenya (58/124) completed
# Kuwait (59/124) completed
# Latvia (60/124) completed
# Libya (61/124) completed
# Liechtenstein (62/124) completed
# Lithuania (63/124) completed
# Luxembourg (64/124) completed
# Madagascar (65/124) completed
# Malawi (66/124) completed
# Malaysia (67/124) completed
# Maldives (68/124) completed
# Malta (69/124) completed
# Mauritania (70/124) completed
# Mexico (71/124) completed
# Mongolia (72/124) completed
# Morocco (73/124) completed
# Mozambique (74/124) completed
# Myanmar (75/124) completed
# Namibia (76/124) completed
# Nepal (77/124) completed
# Netherlands (78/124) completed
# New Zealand (79/124) completed
# Nigeria (80/124) completed
# North Macedonia (81/124) completed
# Norway (82/124) completed
# Oman (83/124) completed
# Pakistan (84/124) completed
# Palestine (85/124) completed
# Panama (86/124) completed
# Paraguay (87/124) completed
# Peru (88/124) completed
# Philippines (89/124) completed
# Poland (90/124) completed
# Poland (91/124) completed
# Portugal (92/124) completed
# Qatar (93/124) completed
# Romania (94/124) completed
# Russia (95/124) completed
# Rwanda (96/124) completed
# Saudi Arabia (97/124) completed
# Senegal (98/124) completed
# Serbia (99/124) completed
# Singapore (100/124) completed
# Slovakia (101/124) completed
# Slovenia (102/124) completed
# South Africa (103/124) completed
# South Korea (104/124) completed
# South Sudan (105/124) completed
# Spain (106/124) completed
# Sri Lanka (107/124) completed
# Sweden (108/124) completed
# Switzerland (109/124) completed
# Taiwan (110/124) could not be found
# Thailand (111/124) completed
# Togo (112/124) completed
# Trinidad and Tobago (113/124) completed
# Tunisia (114/124) completed
# Turkey (115/124) completed
# Uganda (116/124) completed
# Ukraine (117/124) completed
# United Arab Emirates (118/124) completed
# United Kingdom (119/124) completed
# United States (120/124) completed
# Uruguay (121/124) completed
# Vietnam (122/124) completed
# Zambia (123/124) completed
# Zimbabwe (124/124) completed
