# %%
from os import walk
import pandas as pd
import warnings

warnings.filterwarnings('ignore')
files_location = ".\\Parsed Data\\"

# %%
def update_col(old_dataset, new_dataset, col_name):
    if col_name in old_dataset:
        new_dataset[col_name] = old_dataset[col_name]
    else:
        new_dataset[col_name] = ''
    return new_dataset

files = []
for (dirpath, dirnames, filenames) in walk(files_location):
    files.extend(filenames)
    break

file_count = 0
for filename in files:
    data = pd.read_csv(files_location + filename)
    
    new_data = pd.DataFrame()
    col_titles = ['date', 'cases', 'deaths', 'daily_tests', 'lowest_temperature', 'highest_temperature', 'days_since_last_holiday',
                  'people_fully_vaccinated_per_hundred', 'daily_vaccinations_per_million', 'w1_change_cases', 'w1_change_deaths', 'w2_change_cases', 'w2_change_deaths']
    
    for title in col_titles:
        new_data = update_col(data, new_data, title)

    new_data.to_csv(files_location + filename, index=False)
    
    file_count += 1
    print(str(filename) + ' (' + str(file_count) + '/' + str(len(files)) + ') completed')
# Out:
# Afghanistan.csv (1/288) completed
# Alabama.csv (2/288) completed
# Alaska.csv (3/288) completed
# Albania.csv (4/288) completed
# Algeria.csv (5/288) completed
# American Samoa.csv (6/288) completed
# Andorra.csv (7/288) completed
# Angola.csv (8/288) completed
# Anguilla.csv (9/288) completed
# Antigua and Barbuda.csv (10/288) completed
# Argentina.csv (11/288) completed
# Arizona.csv (12/288) completed
# Arkansas.csv (13/288) completed
# Armenia.csv (14/288) completed
# Aruba.csv (15/288) completed
# Australia.csv (16/288) completed
# Austria.csv (17/288) completed
# Azerbaijan.csv (18/288) completed
# Bahamas.csv (19/288) completed
# Bahrain.csv (20/288) completed
# Bangladesh.csv (21/288) completed
# Barbados.csv (22/288) completed
# Belarus.csv (23/288) completed
# Belgium.csv (24/288) completed
# Belize.csv (25/288) completed
# Benin.csv (26/288) completed
# Bermuda.csv (27/288) completed
# Bhutan.csv (28/288) completed
# Bolivia (Plurinational State of).csv (29/288) completed
# Bonaire.csv (30/288) completed
# Bosnia and Herzegovina.csv (31/288) completed
# Botswana.csv (32/288) completed
# Brazil.csv (33/288) completed
# British Virgin Islands.csv (34/288) completed
# Brunei Darussalam.csv (35/288) completed
# Bulgaria.csv (36/288) completed
# Burkina Faso.csv (37/288) completed
# Burundi.csv (38/288) completed
# Cabo Verde.csv (39/288) completed
# California.csv (40/288) completed
# Cambodia.csv (41/288) completed
# Cameroon.csv (42/288) completed
# Canada.csv (43/288) completed
# Cayman Islands.csv (44/288) completed
# Central African Republic.csv (45/288) completed
# Chad.csv (46/288) completed
# Chile.csv (47/288) completed
# China.csv (48/288) completed
# Colombia.csv (49/288) completed
# Colorado.csv (50/288) completed
# Comoros.csv (51/288) completed
# Congo.csv (52/288) completed
# Connecticut.csv (53/288) completed
# Cook Islands.csv (54/288) completed
# Costa Rica.csv (55/288) completed
# Croatia.csv (56/288) completed
# Cuba.csv (57/288) completed
# Curaçao.csv (58/288) completed
# Cyprus.csv (59/288) completed
# Czechia.csv (60/288) completed
# Côte d’Ivoire.csv (61/288) completed
# Delaware.csv (62/288) completed
# Democratic People's Republic of Korea.csv (63/288) completed
# Democratic Republic of the Congo.csv (64/288) completed
# Denmark.csv (65/288) completed
# Djibouti.csv (66/288) completed
# Dominica.csv (67/288) completed
# Dominican Republic.csv (68/288) completed
# Ecuador.csv (69/288) completed
# Egypt.csv (70/288) completed
# El Salvador.csv (71/288) completed
# Equatorial Guinea.csv (72/288) completed
# Eritrea.csv (73/288) completed
# Estonia.csv (74/288) completed
# Eswatini.csv (75/288) completed
# Ethiopia.csv (76/288) completed
# Falkland Islands (Malvinas).csv (77/288) completed
# Faroe Islands.csv (78/288) completed
# Fiji.csv (79/288) completed
# Finland.csv (80/288) completed
# Florida.csv (81/288) completed
# France.csv (82/288) completed
# French Guiana.csv (83/288) completed
# French Polynesia.csv (84/288) completed
# Gabon.csv (85/288) completed
# Gambia.csv (86/288) completed
# Georgia.csv (87/288) completed
# Germany.csv (88/288) completed
# Ghana.csv (89/288) completed
# Gibraltar.csv (90/288) completed
# Greece.csv (91/288) completed
# Greenland.csv (92/288) completed
# Grenada.csv (93/288) completed
# Guadeloupe.csv (94/288) completed
# Guam.csv (95/288) completed
# Guatemala.csv (96/288) completed
# Guernsey.csv (97/288) completed
# Guinea-Bissau.csv (98/288) completed
# Guinea.csv (99/288) completed
# Guyana.csv (100/288) completed
# Haiti.csv (101/288) completed
# Hawaii.csv (102/288) completed
# Holy See.csv (103/288) completed
# Honduras.csv (104/288) completed
# Hungary.csv (105/288) completed
# Iceland.csv (106/288) completed
# Idaho.csv (107/288) completed
# Illinois.csv (108/288) completed
# India.csv (109/288) completed
# Indiana.csv (110/288) completed
# Indonesia.csv (111/288) completed
# Iowa.csv (112/288) completed
# Iran (Islamic Republic of).csv (113/288) completed
# Iraq.csv (114/288) completed
# Ireland.csv (115/288) completed
# Isle of Man.csv (116/288) completed
# Israel.csv (117/288) completed
# Italy.csv (118/288) completed
# Jamaica.csv (119/288) completed
# Japan.csv (120/288) completed
# Jersey.csv (121/288) completed
# Jordan.csv (122/288) completed
# Kansas.csv (123/288) completed
# Kazakhstan.csv (124/288) completed
# Kentucky.csv (125/288) completed
# Kenya.csv (126/288) completed
# Kiribati.csv (127/288) completed
# Kosovo[1].csv (128/288) completed
# Kuwait.csv (129/288) completed
# Kyrgyzstan.csv (130/288) completed
# Lao People's Democratic Republic.csv (131/288) completed
# Latvia.csv (132/288) completed
# Lebanon.csv (133/288) completed
# Lesotho.csv (134/288) completed
# Liberia.csv (135/288) completed
# Libya.csv (136/288) completed
# Liechtenstein.csv (137/288) completed
# Lithuania.csv (138/288) completed
# Louisiana.csv (139/288) completed
# Luxembourg.csv (140/288) completed
# Madagascar.csv (141/288) completed
# Maine.csv (142/288) completed
# Malawi.csv (143/288) completed
# Malaysia.csv (144/288) completed
# Maldives.csv (145/288) completed
# Mali.csv (146/288) completed
# Malta.csv (147/288) completed
# Marshall Islands.csv (148/288) completed
# Martinique.csv (149/288) completed
# Maryland.csv (150/288) completed
# Massachusetts.csv (151/288) completed
# Mauritania.csv (152/288) completed
# Mauritius.csv (153/288) completed
# Mayotte.csv (154/288) completed
# Mexico.csv (155/288) completed
# Michigan.csv (156/288) completed
# Micronesia (Federated States of).csv (157/288) completed
# Minnesota.csv (158/288) completed
# Mississippi.csv (159/288) completed
# Missouri.csv (160/288) completed
# Monaco.csv (161/288) completed
# Mongolia.csv (162/288) completed
# Montana.csv (163/288) completed
# Montenegro.csv (164/288) completed
# Montserrat.csv (165/288) completed
# Morocco.csv (166/288) completed
# Mozambique.csv (167/288) completed
# Myanmar.csv (168/288) completed
# Namibia.csv (169/288) completed
# Nauru.csv (170/288) completed
# Nebraska.csv (171/288) completed
# Nepal.csv (172/288) completed
# Netherlands.csv (173/288) completed
# Nevada.csv (174/288) completed
# New Caledonia.csv (175/288) completed
# New Hampshire.csv (176/288) completed
# New Jersey.csv (177/288) completed
# New Mexico.csv (178/288) completed
# New York.csv (179/288) completed
# New Zealand.csv (180/288) completed
# Nicaragua.csv (181/288) completed
# Niger.csv (182/288) completed
# Nigeria.csv (183/288) completed
# Niue.csv (184/288) completed
# North Carolina.csv (185/288) completed
# North Dakota.csv (186/288) completed
# North Macedonia.csv (187/288) completed
# Northern Mariana Islands (Commonwealth of the).csv (188/288) completed
# Northern Mariana Islands.csv (189/288) completed
# Norway.csv (190/288) completed
# occupied Palestinian territory, including east Jerusalem.csv (191/288) completed
# Ohio.csv (192/288) completed
# Oklahoma.csv (193/288) completed
# Oman.csv (194/288) completed
# Oregon.csv (195/288) completed
# Other.csv (196/288) completed
# Pakistan.csv (197/288) completed
# Palau.csv (198/288) completed
# Panama.csv (199/288) completed
# Papua New Guinea.csv (200/288) completed
# Paraguay.csv (201/288) completed
# Pennsylvania.csv (202/288) completed
# Peru.csv (203/288) completed
# Philippines.csv (204/288) completed
# Pitcairn Islands.csv (205/288) completed
# Poland.csv (206/288) completed
# Portugal.csv (207/288) completed
# Puerto Rico.csv (208/288) completed
# Qatar.csv (209/288) completed
# Republic of Korea.csv (210/288) completed
# Republic of Moldova.csv (211/288) completed
# Rhode Island.csv (212/288) completed
# Romania.csv (213/288) completed
# Russian Federation.csv (214/288) completed
# Rwanda.csv (215/288) completed
# Réunion.csv (216/288) completed
# Saba.csv (217/288) completed
# Saint Barthélemy.csv (218/288) completed
# Saint Kitts and Nevis.csv (219/288) completed
# Saint Lucia.csv (220/288) completed
# Saint Martin.csv (221/288) completed
# Saint Pierre and Miquelon.csv (222/288) completed
# Saint Vincent and the Grenadines.csv (223/288) completed
# Samoa.csv (224/288) completed
# San Marino.csv (225/288) completed
# Sao Tome and Principe.csv (226/288) completed
# Saudi Arabia.csv (227/288) completed
# Senegal.csv (228/288) completed
# Serbia.csv (229/288) completed
# Seychelles.csv (230/288) completed
# Sierra Leone.csv (231/288) completed
# Singapore.csv (232/288) completed
# Sint Eustatius.csv (233/288) completed
# Sint Maarten.csv (234/288) completed
# Slovakia.csv (235/288) completed
# Slovenia.csv (236/288) completed
# Solomon Islands.csv (237/288) completed
# Somalia.csv (238/288) completed
# South Africa.csv (239/288) completed
# South Carolina.csv (240/288) completed
# South Dakota.csv (241/288) completed
# South Sudan.csv (242/288) completed
# Spain.csv (243/288) completed
# Sri Lanka.csv (244/288) completed
# Sudan.csv (245/288) completed
# Suriname.csv (246/288) completed
# Sweden.csv (247/288) completed
# Switzerland.csv (248/288) completed
# Syrian Arab Republic.csv (249/288) completed
# Tajikistan.csv (250/288) completed
# Tennessee.csv (251/288) completed
# Texas.csv (252/288) completed
# Thailand.csv (253/288) completed
# The United Kingdom.csv (254/288) completed
# Timor-Leste.csv (255/288) completed
# Togo.csv (256/288) completed
# Tokelau.csv (257/288) completed
# Tonga.csv (258/288) completed
# Trinidad and Tobago.csv (259/288) completed
# Tunisia.csv (260/288) completed
# Turkey.csv (261/288) completed
# Turkmenistan.csv (262/288) completed
# Turks and Caicos Islands.csv (263/288) completed
# Tuvalu.csv (264/288) completed
# Uganda.csv (265/288) completed
# Ukraine.csv (266/288) completed
# United Arab Emirates.csv (267/288) completed
# United Republic of Tanzania.csv (268/288) completed
# United States of America.csv (269/288) completed
# United States Virgin Islands.csv (270/288) completed
# Uruguay.csv (271/288) completed
# Utah.csv (272/288) completed
# Uzbekistan.csv (273/288) completed
# Vanuatu.csv (274/288) completed
# Venezuela (Bolivarian Republic of).csv (275/288) completed
# Vermont.csv (276/288) completed
# Viet Nam.csv (277/288) completed
# Virgin Islands.csv (278/288) completed
# Virginia.csv (279/288) completed
# Wallis and Futuna.csv (280/288) completed
# Washington DC.csv (281/288) completed
# Washington.csv (282/288) completed
# West Virginia.csv (283/288) completed
# Wisconsin.csv (284/288) completed
# Wyoming.csv (285/288) completed
# Yemen.csv (286/288) completed
# Zambia.csv (287/288) completed
# Zimbabwe.csv (288/288) completed
